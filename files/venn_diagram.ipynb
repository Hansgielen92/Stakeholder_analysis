# %%
import matplotlib.pyplot as plt
import numpy as np
import ipynb
from Testdingen.py import synthesize_assessment_input
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       2 import numpy as np
#       3 import ipynb
# ----> 4 from Testdingen.py import synthesize_assessment_input
#
# ModuleNotFoundError: No module named 'Testdingen'
